# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
data = [  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKmPBggty2mZQ\"",
    "id": "1",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Film & Animation"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45ZTFR3a3NyTA\"",
    "id": "2",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Autos & Vehicles"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxbknKFVe5Lmg\"",
    "id": "10",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Music"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-oBJavSGkfDI\"",
    "id": "15",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Pets & Animals"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM1XVQ9zbGec\"",
    "id": "17",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Sports"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/FJwVpGCVZ1yiJrqZbpqe68Sy_OE\"",
    "id": "18",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Short Movies"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/M-3iD9dwK7YJCafRf_DkLN8CouA\"",
    "id": "19",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Travel & Events"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/WmA0qYEfjWsAoyJFSw2zinhn2wM\"",
    "id": "20",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Gaming"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/EapFaGYG7K0StIXVf8aba249tdM\"",
    "id": "21",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Videoblogging"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZbNIytUQDRo\"",
    "id": "22",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "People & Blogs"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5yaga_Aqtwz8M\"",
    "id": "23",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Comedy"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/UVB9oxX2Bvqa_w_y3vXSLVK5E_s\"",
    "id": "24",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Entertainment"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/QiLK0ZIrFoORdk_g2l_XR_ECjDc\"",
    "id": "25",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "News & Politics"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/r6Ck6Z0_L0rG37VJQR200SGNA_w\"",
    "id": "26",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Howto & Style"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/EoYkczo9I3RCf96RveKTOgOPkUM\"",
    "id": "27",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Education"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ\"",
    "id": "28",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Science & Technology"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/SalkJoBWq_smSEqiAx_qyri6Wa8\"",
    "id": "29",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Nonprofits & Activism"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/lL7uWDr_071CHxifjYG1tJrp4Uo\"",
    "id": "30",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Movies"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/WnuVfjO-PyFLO7NTRQIbrGE62nk\"",
    "id": "31",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Anime/Animation"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/ctpH2hGA_UZ3volJT_FTlOg9M00\"",
    "id": "32",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Action/Adventure"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/L0kR3-g1BAo5UD1PLVbQ7LkkDtQ\"",
    "id": "33",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Classics"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/pUZOAC_s9sfiwar639qr_wAB-aI\"",
    "id": "34",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Comedy"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/Xb5JLhtyNRN3AQq021Ds-OV50Jk\"",
    "id": "35",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Documentary"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/u8WXzF4HIhtEi805__sqjuA4lEk\"",
    "id": "36",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Drama"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/D04PP4Gr7wc4IV_O9G66Z4A8KWQ\"",
    "id": "37",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Family"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/i5-_AceGXQCEEMWU0V8CcQm_vLQ\"",
    "id": "38",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Foreign"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/rtlxd0zOixA9QHdIZB26-St5qgQ\"",
    "id": "39",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Horror"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/N1TrDFLRppxZgBowCJfJCvh0Dpg\"",
    "id": "40",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Sci-Fi/Fantasy"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/7UMGi6zRySqXopr_rv4sZq6Za2E\"",
    "id": "41",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Thriller"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/RScXhi324h8usyIetreAVb-uKeM\"",
    "id": "42",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Shorts"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiGVrFsuFsd0A\"",
    "id": "43",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Shows"
    }
  },
  {
    "kind": "youtube#videoCategory",
    "etag": "\"m2yskBQFythfE4irbTIeOgYYfBU/x5NxSf5fz8hn4loSN4rvhwzD_pY\"",
    "id": "44",
    "snippet": {
      "channelId": "UCBR8-60-B28hp2BmDPdntcQ",
      "title": "Trailers"
    }
  }
]
category = pd.DataFrame.from_dict(json_normalize(data), orient='columns')

category
# Out:
#                                                  etag  id  \
# 0   "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...   1
# 1   "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...   2
# 2   "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...  10
# 3   "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...  15
# 4   "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...  17
# 5   "m2yskBQFythfE4irbTIeOgYYfBU/FJwVpGCVZ1yiJrqZb...  18
# 6   "m2yskBQFythfE4irbTIeOgYYfBU/M-3iD9dwK7YJCafRf...  19
# 7   "m2yskBQFythfE4irbTIeOgYYfBU/WmA0qYEfjWsAoyJFS...  20
# 8   "m2yskBQFythfE4irbTIeOgYYfBU/EapFaGYG7K0StIXVf...  21
# 9   "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...  22
# 10  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...  23
# 11  "m2yskBQFythfE4irbTIeOgYYfBU/UVB9oxX2Bvqa_w_y3...  24
# 12  "m2yskBQFythfE4irbTIeOgYYfBU/QiLK0ZIrFoORdk_g2...  25
# 13  "m2yskBQFythfE4irbTIeOgYYfBU/r6Ck6Z0_L0rG37VJQ...  26
# 14  "m2yskBQFythfE4irbTIeOgYYfBU/EoYkczo9I3RCf96Rv...  27
# 15  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...  28
# 16  "m2yskBQFythfE4irbTIeOgYYfBU/SalkJoBWq_smSEqiA...  29
# 17  "m2yskBQFythfE4irbTIeOgYYfBU/lL7uWDr_071CHxifj...  30
# 18  "m2yskBQFythfE4irbTIeOgYYfBU/WnuVfjO-PyFLO7NTR...  31
# 19  "m2yskBQFythfE4irbTIeOgYYfBU/ctpH2hGA_UZ3volJT...  32
# 20  "m2yskBQFythfE4irbTIeOgYYfBU/L0kR3-g1BAo5UD1PL...  33
# 21  "m2yskBQFythfE4irbTIeOgYYfBU/pUZOAC_s9sfiwar63...  34
# 22  "m2yskBQFythfE4irbTIeOgYYfBU/Xb5JLhtyNRN3AQq02...  35
# 23  "m2yskBQFythfE4irbTIeOgYYfBU/u8WXzF4HIhtEi805_...  36
# 24  "m2yskBQFythfE4irbTIeOgYYfBU/D04PP4Gr7wc4IV_O9...  37
# 25  "m2yskBQFythfE4irbTIeOgYYfBU/i5-_AceGXQCEEMWU0...  38
# 26  "m2yskBQFythfE4irbTIeOgYYfBU/rtlxd0zOixA9QHdIZ...  39
# 27  "m2yskBQFythfE4irbTIeOgYYfBU/N1TrDFLRppxZgBowC...  40
# 28  "m2yskBQFythfE4irbTIeOgYYfBU/7UMGi6zRySqXopr_r...  41
# 29  "m2yskBQFythfE4irbTIeOgYYfBU/RScXhi324h8usyIet...  42
# 30  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...  43
# 31  "m2yskBQFythfE4irbTIeOgYYfBU/x5NxSf5fz8hn4loSN...  44
#
#                      kind         snippet.channelId          snippet.title
# 0   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ       Film & Animation
# 1   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ       Autos & Vehicles
# 2   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                  Music
# 3   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ         Pets & Animals
# 4   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Sports
# 5   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ           Short Movies
# 6   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ        Travel & Events
# 7   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Gaming
# 8   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ          Videoblogging
# 9   youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ         People & Blogs
# 10  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Comedy
# 11  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ          Entertainment
# 12  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ        News & Politics
# 13  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ          Howto & Style
# 14  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ              Education
# 15  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ   Science & Technology
# 16  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ  Nonprofits & Activism
# 17  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Movies
# 18  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ        Anime/Animation
# 19  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ       Action/Adventure
# 20  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ               Classics
# 21  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Comedy
# 22  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ            Documentary
# 23  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                  Drama
# 24  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Family
# 25  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                Foreign
# 26  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Horror
# 27  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ         Sci-Fi/Fantasy
# 28  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ               Thriller
# 29  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                 Shorts
# 30  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ                  Shows
# 31  youtube#videoCategory  UCBR8-60-B28hp2BmDPdntcQ               Trailers

# %%
new_category_table = category[["id", "snippet.channelId", "snippet.title"]].copy()

youtube_category_db = new_category_table.rename(columns={"id" : "category_id",
                                                           "snippet.channelId" :  "channel_id",
                                                           "snippet.title" : "category_title"})
# youtube_category_db.set_index('Category_id', inplace=True)
youtube_category_db
# Out:
#    category_id                channel_id         category_title
# 0            1  UCBR8-60-B28hp2BmDPdntcQ       Film & Animation
# 1            2  UCBR8-60-B28hp2BmDPdntcQ       Autos & Vehicles
# 2           10  UCBR8-60-B28hp2BmDPdntcQ                  Music
# 3           15  UCBR8-60-B28hp2BmDPdntcQ         Pets & Animals
# 4           17  UCBR8-60-B28hp2BmDPdntcQ                 Sports
# 5           18  UCBR8-60-B28hp2BmDPdntcQ           Short Movies
# 6           19  UCBR8-60-B28hp2BmDPdntcQ        Travel & Events
# 7           20  UCBR8-60-B28hp2BmDPdntcQ                 Gaming
# 8           21  UCBR8-60-B28hp2BmDPdntcQ          Videoblogging
# 9           22  UCBR8-60-B28hp2BmDPdntcQ         People & Blogs
# 10          23  UCBR8-60-B28hp2BmDPdntcQ                 Comedy
# 11          24  UCBR8-60-B28hp2BmDPdntcQ          Entertainment
# 12          25  UCBR8-60-B28hp2BmDPdntcQ        News & Politics
# 13          26  UCBR8-60-B28hp2BmDPdntcQ          Howto & Style
# 14          27  UCBR8-60-B28hp2BmDPdntcQ              Education
# 15          28  UCBR8-60-B28hp2BmDPdntcQ   Science & Technology
# 16          29  UCBR8-60-B28hp2BmDPdntcQ  Nonprofits & Activism
# 17          30  UCBR8-60-B28hp2BmDPdntcQ                 Movies
# 18          31  UCBR8-60-B28hp2BmDPdntcQ        Anime/Animation
# 19          32  UCBR8-60-B28hp2BmDPdntcQ       Action/Adventure
# 20          33  UCBR8-60-B28hp2BmDPdntcQ               Classics
# 21          34  UCBR8-60-B28hp2BmDPdntcQ                 Comedy
# 22          35  UCBR8-60-B28hp2BmDPdntcQ            Documentary
# 23          36  UCBR8-60-B28hp2BmDPdntcQ                  Drama
# 24          37  UCBR8-60-B28hp2BmDPdntcQ                 Family
# 25          38  UCBR8-60-B28hp2BmDPdntcQ                Foreign
# 26          39  UCBR8-60-B28hp2BmDPdntcQ                 Horror
# 27          40  UCBR8-60-B28hp2BmDPdntcQ         Sci-Fi/Fantasy
# 28          41  UCBR8-60-B28hp2BmDPdntcQ               Thriller
# 29          42  UCBR8-60-B28hp2BmDPdntcQ                 Shorts
# 30          43  UCBR8-60-B28hp2BmDPdntcQ                  Shows
# 31          44  UCBR8-60-B28hp2BmDPdntcQ               Trailers

# %%
#Connect to local DB
from sqlalchemy import create_engine
rds_connection_string = "postgres:postgres@localhost:5432/youtube_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['videos', 'youtube_category_table']

# %%
youtube_category_db.to_sql(name='youtube_category_table', con=engine, if_exists='append', index=False)
